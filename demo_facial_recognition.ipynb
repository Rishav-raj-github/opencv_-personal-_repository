# %% [markdown]
# # Facial Recognition Demo
#
# This notebook demonstrates the enhanced facial recognition system with Google Images integration and celebrity recognition capabilities.

# %% [markdown]
# ## 1. Setup and Imports

# %%
import sys
import os

# Import facial recognition modules
from facial_recognition_enhanced import CelebrityRecognizer, setup_celebrity_database
from google_images_downloader import GoogleImagesDownloader, setup_celebrity_dataset

print('All modules imported successfully!')

# %% [markdown]
# ## 2. Initialize Celebrity Database

# %%
# Initialize the celebrity recognition system
celebrity_db = setup_celebrity_database()
print(f'Database initialized with {len(celebrity_db)} celebrities')

# %% [markdown]
# ## 3. Download Celebrity Images

# %%
# Download images for training
dataset_info = setup_celebrity_dataset()
print(f'Dataset info: {dataset_info}')

# %% [markdown]
# ## 4. Initialize Facial Recognition

# %%
# Initialize the recognizer
recognizer = CelebrityRecognizer()
print('Facial recognition system initialized')

# %% [markdown]
# ## 5. Recognize Celebrities from Images

# %%
# Example: Recognize celebrity from an image
# image_path = 'path/to/celebrity/image.jpg'
# results = recognizer.recognize_from_image(image_path)
# print(f'Recognition results: {results}')

# %% [markdown]
# ## 6. Batch Recognition

# %%
# Batch process multiple images
# image_folder = 'celebrity_images'
# batch_results = recognizer.batch_recognize(image_folder)
# print(f'Batch recognition completed: {batch_results}')

# %% [markdown]
# ## 7. Performance Metrics

# %%
# Get recognition statistics
# stats = recognizer.get_statistics()
# print(f'Recognition accuracy: {stats["accuracy"]}%')
# print(f'Total faces recognized: {stats["total_recognized"]}')
# print(f'Processing time: {stats["avg_processing_time"]}s')

# %% [markdown]
# ## 8. Results Visualization

# %%
# Visualization code
# import matplotlib.pyplot as plt
# import cv2
# 
# # Display results with bounding boxes
# # results = recognizer.recognize_from_image(image_path, draw_boxes=True)
# # plt.imshow(cv2.cvtColor(results['annotated_image'], cv2.COLOR_BGR2RGB))
# # plt.title('Facial Recognition Results')
# # plt.axis('off')
# # plt.show()
